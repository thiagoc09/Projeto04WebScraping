# %%
from ast import keyword
from email import header
from unicodedata import name
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime


def extracao(page):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    url = f'https://br.indeed.com/jobs?q=Python&l=S%C3%A3o%20Paulo%2C%20SP&start={page}'
    r = requests.get(url, headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup

def transformar(soup):
    divs = soup.find_all('div', class_ = 'job_seen_beacon')
    for item in divs:
        try:
            title = item.find('a').text.strip()
        except: 
            title =''    
        try:
            empresa = item.find('span', class_ = 'companyName').text.strip()
        except: 
            empresa =''    
        loc = item.find('div', class_ = 'companyLocation').text.strip()
        try:
            salario = item.find('div', class_ = 'metadata salary-snippet-container').text.strip()
        except:
            salario = ''
        try:
            resumo = item.find('div', class_ = 'job-snippet').text.strip().replace('\n', '')
        except: 
            resumo =''      
        
        try:
            dataPost = item.find('span', 'date').text
        except:
            dataPost = ''    
        try:
            hoje = datetime.today().strftime('%Y-%m-%d')
        except:
            hoje = ''    
        
        try:
            url_vaga = 'https://www.br.indeed.com' + item.h2.a.get('href')
        except:
            url_vaga = ''    
           
        
        job = {
            'vaga': title,
            'empresa': empresa,
            'localização': loc,
            'salário': salario,
            'dataPostagem':dataPost,
            'dataRaspagem':hoje,
            'requisitos': resumo,
            'job_url':url_vaga
        }
        joblist.append(job)
    return

joblist = []

for i in range(0,30,10):
    print(f'Vaga: {i} ')
    c = extracao(i)
    transformar(c)

df = pd.DataFrame(joblist)

print(df.head())


excel = input("Nome Excel")
df.to_csv(excel+'.csv')
# Out:
# Vaga: 0
# Vaga: 10
# Vaga: 20
#                                 vaga       empresa    localização  \
# 0  Estagiário Precificação e Índices        Anbima  São Paulo, SP
# 1          5915 - Cientista de Dados  GLOBAL HITSS  São Paulo, SP
# 2      Analista Desenvolvedor Python        Shopee  São Paulo, SP
# 3        Desenvolvedor Python Sênior    Innolevels  São Paulo, SP
# 4               Desenvolvedor PYTHON        LLIEGE  São Paulo, SP
#
#                         salário                dataPostagem dataRaspagem  \
# 0                                           Postedhá 4 dias   2022-05-01
# 1                                           Postedhá 2 dias   2022-05-01
# 2                                          Postedhá 12 dias   2022-05-01
# 3  R$ 6.500 - R$ 10.000 por mês             Postedhá 2 dias   2022-05-01
# 4              R$ 6.000 por mês  EmployerAtiva 2 dias atrás   2022-05-01
#
#                                           requisitos  \
# 0  Noções de programação (VBA, Python, SQL, Matla...
# 1  Somos uma empresa do grupo América Móvil, com ...
# 2  VBA e JavaScript serão considerados diferencia...
# 3  Automação de rotinas a frameworks completos de...
# 4  Atuar com programação Fullstack, Django, consu...
#
#                                              job_url
# 0  https://www.indeed.com/rc/clk?jk=80659bdb440d7...
# 1  https://www.indeed.com/rc/clk?jk=fcd6a28daca32...
# 2  https://www.indeed.com/rc/clk?jk=7ac5e47a52506...
# 3  https://www.indeed.com/company/Innolevels/jobs...
# 4  https://www.indeed.com/company/LLIEGE/jobs/Des...
