# %%
from ast import keyword
from email import header
from unicodedata import name
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extracao(page):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    url = f'https://br.indeed.com/jobs?q=gerente%20de%20rh&l=S%C3%A3o%20Paulo%2C%20SP&start={page}'
    r = requests.get(url, headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup

def transformar(soup):
    divs = soup.find_all('div', class_ = 'job_seen_beacon')
    for item in divs:
        try:
            title = item.find('a').text.strip()
        except: 
            title =''    
        try:
            empresa = item.find('span', class_ = 'companyName').text.strip()
        except: 
            empresa =''    
        loc = item.find('div', class_ = 'companyLocation').text.strip()
        try:
            salario = item.find('div', class_ = 'metadata salary-snippet-container').text.strip()
        except:
            salario = ''
        try:
            resumo = item.find('div', class_ = 'job-snippet').text.strip().replace('\n', '')
        except: 
            resumo =''      

        job = {
            'vaga': title,
            'empresa': empresa,
            'localização': loc,
            'salário': salario,
            'requisitos': resumo,
        }
        joblist.append(job)
    return

joblist = []

for i in range(0,150,10):
    print(f'Vaga: {i} ')
    c = extracao(i)
    transformar(c)

df = pd.DataFrame(joblist)

print(df.head())


excel = input("Nome Excel")
df.to_csv(excel+'.csv')
# Out:
# Vaga: 0
# Vaga: 10
# Vaga: 20
# Vaga: 30
# Vaga: 40
# Vaga: 50
# Vaga: 60
# Vaga: 70
# Vaga: 80
# Vaga: 90
# Vaga: 100
# Vaga: 110
# Vaga: 120
# Vaga: 130
# Vaga: 140
#                                           vaga                    empresa  \
# 0                                                  VIS SAVOUR BOULANGERIE
# 1                                     +1 local                  Viva Food
# 2       Vagas de emprego: HOTEL REGIAO JARDINS       HOTEL REGIAO JARDINS
# 3  Vagas de emprego: oficina da comida caseira  oficina da comida caseira
# 4                                      MERCURE                    MERCURE
#
#              localização                      salário  \
# 0          São Paulo, SP             R$ 1.800 por mês
# 1  São Paulo, SP+1 local  R$ 1.600 - R$ 1.700 por mês
# 2          São Paulo, SP  R$ 2.800 - R$ 3.500 por mês
# 3          São Paulo, SP             R$ 2.000 por mês
# 4          São Paulo, SP
#
#                                           requisitos
# 0  Vaga para cozinheiro(a) profissional na região...
# 1  Atuar de segunda-feira a Sexta-feira das 06hrs...
# 2                              VAGA DAS 15H A 23H20.
# 3  Restaurante comida caseira e refeições congela...
# 4  Montar pratos individuais, buffets, bandejas e...
