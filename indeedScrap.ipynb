# %%
from ast import keyword
from email import header
from unicodedata import name
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime


def extracao(page):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    url = f'https://br.indeed.com/jobs?q=Java&l=S%C3%A3o%20Paulo%2C%20SP&start={page}'
    r = requests.get(url, headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup

def transformar(soup):
    divs = soup.find_all('div', class_ = 'job_seen_beacon')
    for item in divs:
        try:
            title = item.find('a').text.strip()
        except: 
            title =''    
        try:
            empresa = item.find('span', class_ = 'companyName').text.strip()
        except: 
            empresa =''    
        loc = item.find('div', class_ = 'companyLocation').text.strip()
        try:
            salario = item.find('div', class_ = 'metadata salary-snippet-container').text.strip()
        except:
            salario = ''
        try:
            resumo = item.find('div', class_ = 'job-snippet').text.strip().replace('\n', '')
        except: 
            resumo =''      
        
        try:
            dataPost = item.find('span', 'date').text
        except:
            dataPost = ''    
        try:
            hoje = datetime.today().strftime('%Y-%m-%d')
        except:
            hoje = ''    
        
        try:
            url_vaga = 'https://www.br.indeed.com' + item.h2.a.get('href')
        except:
            url_vaga = ''    
           
        
        job = {
            'vaga': title,
            'empresa': empresa,
            'localizacao': loc,
            'salario': salario,
            'dataPostagem':dataPost,
            'dataRaspagem':hoje,
            'requisitos': resumo,
            'job_url':url_vaga
        }
        joblist.append(job)
    return

joblist = []

for i in range(0,30,10):
    print(f'Vaga: {i} ')
    c = extracao(i)
    transformar(c)

df = pd.DataFrame(joblist)

#print(df.head())


excel = input("Nome Excel")
df.to_csv(excel+'.csv')
# Out:
# Vaga: 0
# Vaga: 10
# Vaga: 20
#                                          vaga               empresa  \
# 0                          Desenvolvedor Java            Innolevels
# 1           Assistente de TI (Banco de Dados)            Entreposto
# 2                    Desenvolvedor(a) Java PL  Recrutamento Externo
# 3  Pessoa Desenvolvedora Backend Pleno (JAVA)       Mercado Bitcoin
# 4                           ESPECIALISTA JAVA               Bionexo
#
#                     localizacao                      salario  \
# 0                 São Paulo, SP  R$ 3.600 - R$ 5.600 por mês
# 1                 São Paulo, SP  R$ 1.800 - R$ 2.100 por mês
# 2                 São Paulo, SP
# 3  Home office in São Paulo, SP
# 4  Home office in São Paulo, SP
#
#                  dataPostagem dataRaspagem  \
# 0  EmployerAtiva 5 dias atrás   2022-05-01
# 1             Postedhá 8 dias   2022-05-01
# 2             Postedhá 3 dias   2022-05-01
# 3            Postedhá 10 dias   2022-05-01
# 4             Postedhá 5 dias   2022-05-01
#
#                                           requisitos  \
# 0  Junit ou outras ferramentas de Teste.Candidate...
# 1  Conhecimento em banco de dados (SQL) - Java di...
# 2  Sua missão será desenvolver softwares seguros,...
# 3  Desenvolver software (com testes) pronto para ...
# 4  A *Bionexo* é uma *healthtech* brasileira que ...
#
#                                              job_url
# 0  https://www.br.indeed.com/company/Innolevels/j...
# 1  https://www.br.indeed.com/company/Entreposto/j...
# 2  https://www.br.indeed.com/rc/clk?jk=4da65d3a23...
# 3  https://www.br.indeed.com/rc/clk?jk=c56536bf16...
# 4  https://www.br.indeed.com/company/BIONEXO/jobs...
