# %%
from ast import keyword
from email import header
from unicodedata import name
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extracao(page):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    url = f'https://br.indeed.com/jobs?q=python&l=S%C3%A3o%20Paulo%2C%20SP&start={page}'
    r = requests.get(url, headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup

def transformar(soup):
    divs = soup.find_all('div', class_ = 'job_seen_beacon')
    for item in divs:
       
        title = item.find('a').text.strip()
        try:
            empresa = item.find('span', class_ = 'companyName').text.strip()
        except: 
            empresa =''    
        loc = item.find('div', class_ = 'companyLocation').text.strip()
        try:
            salario = item.find('div', class_ = 'metadata salary-snippet-container').text.strip()
        except:
            salario = ''
        resumo = item.find('div', class_ = 'job-snippet').text.strip().replace('\n', '')

        job = {
            'vaga': title,
            'empresa': empresa,
            'localização': loc,
            'salário': salario,
            'requisitos': resumo,
        }
        joblist.append(job)
    return

joblist = []

for i in range(0,150,10):
    print(f'Vaga: {i} ')
    c = extracao(i)
    transformar(c)

df = pd.DataFrame(joblist)

print(df.head())

df.to_csv('Python5.csv')
# Out:
# Vaga: 0
# Vaga: 10
# Vaga: 20
# Vaga: 30
# Vaga: 40
# Vaga: 50
# Vaga: 60
# Vaga: 70
# Vaga: 80
# Vaga: 90
# Vaga: 100
# Vaga: 110
# Vaga: 120
# Vaga: 130
# Vaga: 140
#                                 vaga       empresa    localização  \
# 0  Estagiário Precificação e Índices        Anbima  São Paulo, SP
# 1          5915 - Cientista de Dados  GLOBAL HITSS  São Paulo, SP
# 2      Analista Desenvolvedor Python        Shopee  São Paulo, SP
# 3               Desenvolvedor PYTHON        LLIEGE  São Paulo, SP
# 4        Desenvolvedor Python Sênior    Innolevels  São Paulo, SP
#
#                         salário  \
# 0
# 1
# 2
# 3              R$ 6.000 por mês
# 4  R$ 6.500 - R$ 10.000 por mês
#
#                                           requisitos
# 0  Noções de programação (VBA, Python, SQL, Matla...
# 1  Somos uma empresa do grupo América Móvil, com ...
# 2  VBA e JavaScript serão considerados diferencia...
# 3  Atuar com programação Fullstack, Django, consu...
# 4  Automação de rotinas a frameworks completos de...
